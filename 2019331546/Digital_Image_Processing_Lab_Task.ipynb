# %% [markdown]
# <a href="https://colab.research.google.com/github/majedSD/Assignment-Digital-Image-Processing/blob/main/Digital_Image_Processing_Lab_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img1=cv2.imread("/content/sample_data/P1.png")
img2=cv2.imread("/content/sample_data/P1.png")
cv2_imshow(img1)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=560x343>
# <PIL.Image.Image image mode=RGB size=560x343>

# %% [markdown]
# Addition images
# =>Noise Reduction

# %%
img1=cv2.resize(img1,(300,300))
img2=cv2.resize(img2,(300,300))
img_add=cv2.add(img1,img2)
cv2_imshow(img_add)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# Subtraction
# =>Change detection

# %%
img_sub=cv2.subtract(img1,img2)
cv2_imshow(img_sub)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# Multiplication
# =>Masking

# %%
img_mul=cv2.multiply(img1,img2)
cv2_imshow(img_mul)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
